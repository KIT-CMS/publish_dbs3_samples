# %%
from rucio.client.client import Client
import os
import re
import json
from rucio_helper import setup_rucio_account
# set environment variable RUCIO_CONFIG
os.environ['RUCIO_CONFIG'] = '/work/sbrommer/embedding/publish_ul_samples/rucio.cfg'

# %%
setup_rucio_account()
client = Client()
# Out:
# Using rucio account sbrommer

# %%
def get_account_rules(account, defaultname):
    sample_names = []
    transfered_samples = []
    request_details = client.list_account_rules(account=account)
    for i, request in enumerate(request_details):
        if request['state'] == 'OK' and defaultname in request['name']:
            transfered_samples.append(request)
            # if i == 0:
            #     print(request)
            if request['name'] in sample_names:
                print("Duplicate sample name found: ", request['name'])
            sample_names.append(request['name'])
        else:
            print(request['name'], request['state'])
    print(f"Successfully transfered samples: {len(transfered_samples)} / {6*(18)}")
    return transfered_samples


def get_block_files(block, scope):
    files = client.list_files(scope=scope, name=block)
    return list(files)


def get_rucio_blocks(scope, account, samplename):
    # in rucio, different naming is used:
    # containers -> datasets
    # datasets -> blocks
    # get the full list of available blocks
    results = client.list_dids(scope=scope, filters={'account': account}, did_type='dataset', long=True)
    # now filter the list so only matching blocks are returned
    results = [block for block in results if re.search(samplename, block['name'])]
    slim_results = []
    for block in list(results):
        files = get_block_files(block['name'], scope)
        slim_results.append({'blockname': block['name'], 'files': files})
    return slim_results

# %%
# defaults
account = 'pog_tau_group'
scope = 'group.pog_tau_group'
defaultname = 'inputDoubleMu_106X_ULegacy_miniAOD'

transfered_samples = get_account_rules(account, defaultname)
data = {}
for sample in transfered_samples:
    rucio_data = get_rucio_blocks(scope, account, sample['name'])
    data[sample['name']] = rucio_data
    print(f"Sample: {sample['name']}")
    print(f"Number of blocks: {len(rucio_data)}")
    print(f"Number of files: {sum([len(rucio_data[x]['files']) for x in range(len(rucio_data))])}")
# Out:
# Successfully transfered samples: 108 / 108
# Sample: /EmbeddingRun2016_G/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 16
# Number of files: 153
# Sample: /EmbeddingRun2016_G/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 16
# Number of files: 153
# Sample: /EmbeddingRun2018A/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 26
# Number of files: 253
# Sample: /EmbeddingRun2016_H/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 17
# Number of files: 165
# Sample: /EmbeddingRun2016-HIPM_E/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 95
# Sample: /EmbeddingRun2017F/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 26
# Number of files: 258
# Sample: /EmbeddingRun2016-HIPM_E/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 95
# Sample: /EmbeddingRun2018B/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 117
# Sample: /EmbeddingRun2016_G/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 16
# Number of files: 153
# Sample: /EmbeddingRun2018B/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 117
# Sample: /EmbeddingRun2017F/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 27
# Number of files: 262
# Sample: /EmbeddingRun2016_G/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 16
# Number of files: 153
# Sample: /EmbeddingRun2016-HIPM_B_ver1/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 2
# Number of files: 14
# Sample: /EmbeddingRun2016_H/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 17
# Number of files: 165
# Sample: /EmbeddingRun2016_G/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 16
# Number of files: 153
# Sample: /EmbeddingRun2016_G/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 16
# Number of files: 153
# Sample: /EmbeddingRun2016_H/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 17
# Number of files: 165
# Sample: /EmbeddingRun2016-HIPM_B_ver1/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 2
# Number of files: 14
# Sample: /EmbeddingRun2017C/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 17
# Number of files: 169
# Sample: /EmbeddingRun2016-HIPM_B_ver1/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 2
# Number of files: 14
# Sample: /EmbeddingRun2016_F/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 2
# Number of files: 18
# Sample: /EmbeddingRun2016_F/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 1
# Number of files: 9
# Sample: /EmbeddingRun2016-HIPM_B_ver1/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 2
# Number of files: 14
# Sample: /EmbeddingRun2016_F/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 1
# Number of files: 9
# Sample: /EmbeddingRun2016-HIPM_B_ver1/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 2
# Number of files: 14
# Sample: /EmbeddingRun2016_F/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 1
# Number of files: 9
# Sample: /EmbeddingRun2016-HIPM_B_ver1/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 2
# Number of files: 14
# Sample: /EmbeddingRun2016_F/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 1
# Number of files: 9
# Sample: /EmbeddingRun2016_F/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 1
# Number of files: 9
# Sample: /EmbeddingRun2018D/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 57
# Number of files: 561
# Sample: /EmbeddingRun2017B/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 6
# Number of files: 59
# Sample: /EmbeddingRun2017B/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 6
# Number of files: 60
# Sample: /EmbeddingRun2016-HIPM_B_ver2/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 28
# Number of files: 276
# Sample: /EmbeddingRun2017F/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 26
# Number of files: 257
# Sample: /EmbeddingRun2017E/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 18
# Number of files: 178
# Sample: /EmbeddingRun2016-HIPM_D/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 113
# Sample: /EmbeddingRun2018A/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 26
# Number of files: 253
# Sample: /EmbeddingRun2017D/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 98
# Sample: /EmbeddingRun2017F/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 26
# Number of files: 259
# Sample: /EmbeddingRun2016-HIPM_D/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 113
# Sample: /EmbeddingRun2017D/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 98
# Sample: /EmbeddingRun2017C/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 17
# Number of files: 170
# Sample: /EmbeddingRun2017D/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 94
# Sample: /EmbeddingRun2018D/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 57
# Number of files: 561
# Sample: /EmbeddingRun2016-HIPM_E/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 95
# Sample: /EmbeddingRun2016-HIPM_F/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 6
# Number of files: 60
# Sample: /EmbeddingRun2018B/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 117
# Sample: /EmbeddingRun2017C/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 17
# Number of files: 166
# Sample: /EmbeddingRun2016-HIPM_F/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 6
# Number of files: 60
# Sample: /EmbeddingRun2018D/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 57
# Number of files: 561
# Sample: /EmbeddingRun2017E/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 18
# Number of files: 174
# Sample: /EmbeddingRun2017B/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 6
# Number of files: 60
# Sample: /EmbeddingRun2016-HIPM_F/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 6
# Number of files: 60
# Sample: /EmbeddingRun2017E/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 18
# Number of files: 177
# Sample: /EmbeddingRun2017E/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 18
# Number of files: 177
# Sample: /EmbeddingRun2017D/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 100
# Sample: /EmbeddingRun2017F/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 26
# Number of files: 259
# Sample: /EmbeddingRun2018B/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 117
# Sample: /EmbeddingRun2018C/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 115
# Sample: /EmbeddingRun2016-HIPM_B_ver2/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 28
# Number of files: 276
# Sample: /EmbeddingRun2016-HIPM_D/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 113
# Sample: /EmbeddingRun2017B/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 6
# Number of files: 56
# Sample: /EmbeddingRun2018B/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 117
# Sample: /EmbeddingRun2018A/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 26
# Number of files: 252
# Sample: /EmbeddingRun2018A/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 26
# Number of files: 253
# Sample: /EmbeddingRun2017D/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 98
# Sample: /EmbeddingRun2016-HIPM_B_ver2/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 28
# Number of files: 276
# Sample: /EmbeddingRun2016-HIPM_F/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 6
# Number of files: 60
# Sample: /EmbeddingRun2017C/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 17
# Number of files: 170
# Sample: /EmbeddingRun2016-HIPM_D/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 113
# Sample: /EmbeddingRun2016-HIPM_C/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 94
# Sample: /EmbeddingRun2016_H/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 17
# Number of files: 165
# Sample: /EmbeddingRun2017E/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 18
# Number of files: 179
# Sample: /EmbeddingRun2016-HIPM_C/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 94
# Sample: /EmbeddingRun2016-HIPM_E/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 95
# Sample: /EmbeddingRun2017C/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 17
# Number of files: 168
# Sample: /EmbeddingRun2016-HIPM_F/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 6
# Number of files: 60
# Sample: /EmbeddingRun2018A/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 26
# Number of files: 252
# Sample: /EmbeddingRun2018C/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 115
# Sample: /EmbeddingRun2017E/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 18
# Number of files: 177
# Sample: /EmbeddingRun2016-HIPM_C/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 94
# Sample: /EmbeddingRun2018D/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 57
# Number of files: 561
# Sample: /EmbeddingRun2016-HIPM_E/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 95
# Sample: /EmbeddingRun2016-HIPM_C/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 94
# Sample: /EmbeddingRun2018C/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 115
# Sample: /EmbeddingRun2017B/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 7
# Number of files: 62
# Sample: /EmbeddingRun2016-HIPM_F/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 6
# Number of files: 60
# Sample: /EmbeddingRun2017B/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 6
# Number of files: 60
# Sample: /EmbeddingRun2016-HIPM_D/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 113
# Sample: /EmbeddingRun2018D/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 57
# Number of files: 562
# Sample: /EmbeddingRun2016_H/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 17
# Number of files: 165
# Sample: /EmbeddingRun2018B/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 117
# Sample: /EmbeddingRun2016-HIPM_B_ver2/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 28
# Number of files: 276
# Sample: /EmbeddingRun2016-HIPM_C/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 94
# Sample: /EmbeddingRun2017C/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 17
# Number of files: 170
# Sample: /EmbeddingRun2016-HIPM_C/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 94
# Sample: /EmbeddingRun2017D/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 98
# Sample: /EmbeddingRun2018C/ElTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 115
# Sample: /EmbeddingRun2016-HIPM_D/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 113
# Sample: /EmbeddingRun2016-HIPM_B_ver2/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 28
# Number of files: 276
# Sample: /EmbeddingRun2018A/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 26
# Number of files: 253
# Sample: /EmbeddingRun2018C/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 115
# Sample: /EmbeddingRun2018D/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 57
# Number of files: 562
# Sample: /EmbeddingRun2017F/ElectronEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 26
# Number of files: 258
# Sample: /EmbeddingRun2016-HIPM_E/TauTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 10
# Number of files: 95
# Sample: /EmbeddingRun2016_H/MuTauFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 17
# Number of files: 165
# Sample: /EmbeddingRun2018C/ElMuFinalState-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 12
# Number of files: 115
# Sample: /EmbeddingRun2016-HIPM_B_ver2/MuonEmbedding-inputDoubleMu_106X_ULegacy_miniAOD-v1/USER
# Number of blocks: 28
# Number of files: 276

# %%
# dump data into json file
json.dump(data, open('rucio_data.json', 'w'), indent=4)
